# %%
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import matplotlib.cm as cm

import sys
import os
#project_root = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
#sys.path.append(project_root)
#from utils.analysis_funcs import *
from analysis_funcs import *

# %%
title_fontsize = 16
labels_fontsize = 20
ticks_fontsize = 16

# Customizing fonts globally (optional, can be changed)
plt.rcParams.update({
    'font.family': 'serif',  # Choose a serif font
    'font.serif': ['Times New Roman'],  # Set to Times New Roman (if available)
    'font.size': 14,  # Adjust default font size
    'axes.titlesize': 16,  # Title font size
    'axes.labelsize': 14,  # Label font size
    'legend.fontsize': 12,  # Legend font size
})

# %%
def RUSA_load_data(full_file_path, update_num=-2, verbose=False, static=False):
    '''I am not sure where exactly 800 is coming from...'''
    #times_idx=0
    filt_emg_idx=2
    dec_idx=3
    p_act_idx=8
    #v_dec_idx=9
    #v_int_idx=10
    p_ref_idx=7
    
    if update_num==-2:
        init_idx = -1600
        final_idx = -800
    elif update_num==-1:
        init_idx = -800
        final_idx = -1
    elif update_num==0:
        init_idx = 0
        final_idx = 800
    else:
        raise ValueError(f"update_num {update_num} not supported, please use 0, -1, or -2!")
        
    if not static:
        #print("Loading Data")
        try:
            with h5py.File(full_file_path, 'r') as handle:
                weiner_dataset = handle['weiner']
                weiner_df = pd.DataFrame(weiner_dataset)

            # Get the last 1600 points and then only keep points from -1600 to -800
            weiner_df = weiner_df.iloc[-1600:final_idx]

            # Create lists for the remaining data
            dec_lst = [weiner_df.iloc[i, 0][dec_idx] for i in range(weiner_df.shape[0])]
            emg_lst = [weiner_df.iloc[i, 0][filt_emg_idx] for i in range(weiner_df.shape[0])]
            pref_lst = [weiner_df.iloc[i, 0][p_ref_idx] for i in range(weiner_df.shape[0])]
            pact_lst = [weiner_df.iloc[i, 0][p_act_idx] for i in range(weiner_df.shape[0])]

            #print("Successfully loaded in all data and set lists!")

            # Convert each array to a tuple (hashable) to ensure uniqueness, then back to NumPy arrays
            #unique_dec_lst = np.unique([tuple(arr) for arr in dec_lst], axis=0)
            # If you need the result back as a list of numpy arrays
            #unique_dec_lst = [np.array(tup) for tup in unique_dec_lst]

            return dec_lst, emg_lst, pref_lst, pact_lst#, vint_lst, vdec_lst
        except OSError:
            print(f"Unable to open/find file: {full_file_path}\nThus, downstream will be dummy values of -1")
            return [], [], [], []#, [], []
    
def return_final_averaged_cost_and_tdposerror(full_file_path, update_num=-2):
    dec_lst, emg_lst, pref_lst, pact_lst = RUSA_load_data(full_file_path, update_num=update_num, verbose=False, static=False)
    if len(dec_lst)==0:
        return -1, -1
    else:
        cost_log, perf_log, penalty_log = calc_cost_function(emg_lst, dec_lst, pref_lst, pact_lst)
        #filtered_data = remove_spikes_via_IQR(data, k=1.5)
        td_error = calc_time_domain_error(np.array(pref_lst), np.array(pact_lst))
        return np.mean(cost_log), np.mean(td_error)

# %% [markdown]
# ## LOADING PILOT STUDY DATA

# %%
# Function to extract cost and time-domain performance
def extract_performance(file_dict):
    results = {}
    for key, file_path in file_dict.items():
        mean_cost, mean_tdpe = return_final_averaged_cost_and_tdposerror(file_path)
        results[key] = {
            'mean_cost': mean_cost,
            'mean_tdpe': mean_tdpe
        }
    return results

# %%
# Define block and condition names
blocks = ['Block1', 'Block2']
conditions = [
    'C0_local_random_init', 'C1_local_prev_local_init', 'C2_local_sims_init', 
    'C3_StaticTrial', 'C4_pfa_random_init', 'C5_pfa_sims_init', 
    'C6_pfa_running_random', 'C7_pfa_running_sim'
]

# %%
SUBJECT_STR = "S100"

# FILE PATHS
BASEPATH_BRC = r'D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\' + SUBJECT_STR 
basepath = BASEPATH_BRC

# Store file paths in a dictionary
file_paths = {
    f'{block}_{condition}': f"{basepath}\\weiner_IMWUT25_{SUBJECT_STR}_{block}_{condition}.h5"
    for block in blocks
    for condition in conditions
}

# Extract cost and time-domain performance for all logs
S100_performance_results = extract_performance(file_paths)

# Example access to results
# For Block 1, Condition C0
print(S100_performance_results['Block1_C0_local_random_init']['mean_cost'])

# For Block 2, Condition C7
print(S100_performance_results['Block2_C7_pfa_running_sim']['mean_tdpe'])
# Out:
# 0.001423592278506306
# 22.963177540329085

# %%
SUBJECT_STR = "S101"

# FILE PATHS
BASEPATH_BRC = r'D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\' + SUBJECT_STR 
basepath = BASEPATH_BRC

file_paths = {
    f'{block}_{condition}': f"{basepath}\\weiner_IMWUT25_{SUBJECT_STR}_{block}_{condition}.h5"
    for block in blocks
    for condition in conditions
}
S101_performance_results = extract_performance(file_paths)

# %%
SUBJECT_STR = "S102"

# FILE PATHS
BASEPATH_BRC = r'D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\' + SUBJECT_STR 
basepath = BASEPATH_BRC

file_paths = {
    f'{block}_{condition}': f"{basepath}\\weiner_IMWUT25_{SUBJECT_STR}_{block}_{condition}.h5"
    for block in blocks
    for condition in conditions
}
S102_performance_results = extract_performance(file_paths)

# %%
SUBJECT_STR = "S103"

# FILE PATHS
BASEPATH_BRC = r'D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\' + SUBJECT_STR 
basepath = BASEPATH_BRC

file_paths = {
    f'{block}_{condition}': f"{basepath}\\weiner_IMWUT25_{SUBJECT_STR}_{block}_{condition}.h5"
    for block in blocks
    for condition in conditions
}
S103_performance_results = extract_performance(file_paths)

# %%
SUBJECT_STR = "S104"

# FILE PATHS
BASEPATH_BRC = r'D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\' + SUBJECT_STR 
basepath = BASEPATH_BRC

file_paths = {
    f'{block}_{condition}': f"{basepath}\\weiner_IMWUT25_{SUBJECT_STR}_{block}_{condition}.h5"
    for block in ['Block1'] #blocks  # Forgot/missing C2 in B2...
    for condition in conditions
}
S104_performance_results = extract_performance(file_paths)

# %%
SUBJECT_STR = "S105"

# FILE PATHS
BASEPATH_BRC = r'D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\' + SUBJECT_STR 
basepath = BASEPATH_BRC

file_paths = {
    f'{block}_{condition}': f"{basepath}\\weiner_IMWUT25_{SUBJECT_STR}_{block}_{condition}.h5"
    for block in blocks
    for condition in conditions
}
S105_performance_results = extract_performance(file_paths)

# %%
SUBJECT_STR = "S106"

# FILE PATHS
BASEPATH_BRC = r'D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\' + SUBJECT_STR 
basepath = BASEPATH_BRC

file_paths = {
    f'{block}_{condition}': f"{basepath}\\weiner_IMWUT25_{SUBJECT_STR}_{block}_{condition}.h5"
    for block in ['Block1'] #blocks  # Forgot/missing C1 in B2...
    for condition in conditions
}
S106_performance_results = extract_performance(file_paths)

# %%
SUBJECT_STR = "S107"

# FILE PATHS
BASEPATH_BRC = r'D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\' + SUBJECT_STR 
basepath = BASEPATH_BRC

file_paths = {
    f'{block}_{condition}': f"{basepath}\\weiner_IMWUT25_{SUBJECT_STR}_{block}_{condition}.h5"
    for block in blocks
    for condition in conditions
}
S107_performance_results = extract_performance(file_paths)
# Out:
# Unable to open/find file: D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\S107\weiner_IMWUT25_S107_Block2_C1_local_prev_local_init.h5
# Thus, downstream will be dummy values of -1
# Unable to open/find file: D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\S107\weiner_IMWUT25_S107_Block2_C3_StaticTrial.h5
# Thus, downstream will be dummy values of -1
# Unable to open/find file: D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\S107\weiner_IMWUT25_S107_Block2_C5_pfa_sims_init.h5
# Thus, downstream will be dummy values of -1

# %%
SUBJECT_STR = "S108"

# FILE PATHS
BASEPATH_BRC = r'D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\' + SUBJECT_STR 
basepath = BASEPATH_BRC

file_paths = {
    f'{block}_{condition}': f"{basepath}\\weiner_IMWUT25_{SUBJECT_STR}_{block}_{condition}.h5"
    for block in blocks
    for condition in conditions
}
S108_performance_results = extract_performance(file_paths)

# %%
SUBJECT_STR = "S109"

# FILE PATHS
BASEPATH_BRC = r'D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\' + SUBJECT_STR 
basepath = BASEPATH_BRC

file_paths = {
    f'{block}_{condition}': f"{basepath}\\weiner_IMWUT25_{SUBJECT_STR}_{block}_{condition}.h5"
    for block in blocks
    for condition in conditions
}
S109_performance_results = extract_performance(file_paths)

# %%
SUBJECT_STR = "S110"

# FILE PATHS
BASEPATH_BRC = r'D:\\Kai_CPHS_23_24\\lgrice_dir\\user_study\\' + SUBJECT_STR 
basepath = BASEPATH_BRC

file_paths = {
    f'{block}_{condition}': f"{basepath}\\weiner_IMWUT25_{SUBJECT_STR}_{block}_{condition}.h5"
    for block in blocks
    for condition in conditions
}
S110_performance_results = extract_performance(file_paths)

# %%
perf_dicts_lst = [S100_performance_results, S101_performance_results, S102_performance_results, 
                  S103_performance_results, S104_performance_results, S105_performance_results, 
                  S106_performance_results, S107_performance_results, S108_performance_results,
                  S109_performance_results, S110_performance_results]

lri_c0_cost = [perf_dict['Block1_C0_local_random_init']['mean_cost'] for perf_dict in perf_dicts_lst]
lpli_c1_cost = [perf_dict['Block1_C1_local_prev_local_init']['mean_cost'] for perf_dict in perf_dicts_lst]
lsi_c2_cost = [perf_dict['Block1_C2_local_sims_init']['mean_cost'] for perf_dict in perf_dicts_lst]
st_c3_cost = [perf_dict['Block1_C3_StaticTrial']['mean_cost'] for perf_dict in perf_dicts_lst]
pri_c4_cost = [perf_dict['Block1_C4_pfa_random_init']['mean_cost'] for perf_dict in perf_dicts_lst]
psi_c5_cost = [perf_dict['Block1_C5_pfa_sims_init']['mean_cost'] for perf_dict in perf_dicts_lst]
prr_c6_cost = [perf_dict['Block1_C6_pfa_running_random']['mean_cost'] for perf_dict in perf_dicts_lst]
prs_c7_cost = [perf_dict['Block1_C7_pfa_running_sim']['mean_cost'] for perf_dict in perf_dicts_lst]

lri_c0_tdpe = [perf_dict['Block1_C0_local_random_init']['mean_tdpe'] for perf_dict in perf_dicts_lst]
lpli_c1_tdpe = [perf_dict['Block1_C1_local_prev_local_init']['mean_tdpe'] for perf_dict in perf_dicts_lst]
lsi_c2_tdpe = [perf_dict['Block1_C2_local_sims_init']['mean_tdpe'] for perf_dict in perf_dicts_lst]
st_c3_tdpe = [perf_dict['Block1_C3_StaticTrial']['mean_tdpe'] for perf_dict in perf_dicts_lst]
pri_c4_tdpe = [perf_dict['Block1_C4_pfa_random_init']['mean_tdpe'] for perf_dict in perf_dicts_lst]
psi_c5_tdpe = [perf_dict['Block1_C5_pfa_sims_init']['mean_tdpe'] for perf_dict in perf_dicts_lst]
prr_c6_tdpe = [perf_dict['Block1_C6_pfa_running_random']['mean_tdpe'] for perf_dict in perf_dicts_lst]
prs_c7_tdpe = [perf_dict['Block1_C7_pfa_running_sim']['mean_tdpe'] for perf_dict in perf_dicts_lst]


# PILOT STUDY RESULTS!
#lri_c0_cost = [s0_b1_c0_lri_mean_cost, s1_lri_B1_mean_cost]
#lpli_c1_cost = [s0_b1_c1_lri_mean_cost, s1_lpli_B1_mean_cost]
#lsi_c2_cost = [s0_b1_c2_lsi_mean_cost, s1_lsi_B1_mean_cost]
#st_c3_cost = [s0_b1_c3_st_mean_cost, s1_st_B1_mean_cost]
#pri_c4_cost = [s0_b1_c4_pri_mean_cost, s1_pri_B1_mean_cost]
#psi_c5_cost = [s0_b1_c5_psi_mean_cost, s1_psi_B1_mean_cost]
#prr_c6_cost = [s0_b1_c6_prr_mean_cost, s1_prr_B1_mean_cost]
#prs_c7_cost = [s0_b1_c7_prs_mean_cost, s1_prs_B1_mean_cost]

#lri_c0_tdpe = [s0_b1_c0_lri_mean_tdpe, s1_lri_B1_mean_tdpe]
#lpli_c1_tdpe = [s0_b1_c1_lri_mean_tdpe, s1_lpli_B1_mean_tdpe]
#lsi_c2_tdpe = [s0_b1_c2_lsi_mean_tdpe, s1_lsi_B1_mean_tdpe]
#st_c3_tdpe = [s0_b1_c3_st_mean_tdpe, s1_st_B1_mean_tdpe]
#pri_c4_tdpe = [s0_b1_c4_pri_mean_tdpe, s1_pri_B1_mean_tdpe]
#psi_c5_tdpe = [s0_b1_c5_psi_mean_tdpe, s1_psi_B1_mean_tdpe]
#prr_c6_tdpe = [s0_b1_c6_prr_mean_tdpe, s1_prr_B1_mean_tdpe]
#prs_c7_tdpe = [s0_b1_c7_prs_mean_tdpe, s1_prs_B1_mean_tdpe]

# %%
# Removing negative values from cost lists
lri_c0_cost = [cost for cost in lri_c0_cost if cost >= 0]
lpli_c1_cost = [cost for cost in lpli_c1_cost if cost >= 0]
lsi_c2_cost = [cost for cost in lsi_c2_cost if cost >= 0]
st_c3_cost = [cost for cost in st_c3_cost if cost >= 0]
pri_c4_cost = [cost for cost in pri_c4_cost if cost >= 0]
psi_c5_cost = [cost for cost in psi_c5_cost if cost >= 0]
prr_c6_cost = [cost for cost in prr_c6_cost if cost >= 0]
prs_c7_cost = [cost for cost in prs_c7_cost if cost >= 0]

# Removing negative values from tdpe lists
lri_c0_tdpe = [tdpe for tdpe in lri_c0_tdpe if tdpe >= 0]
lpli_c1_tdpe = [tdpe for tdpe in lpli_c1_tdpe if tdpe >= 0]
lsi_c2_tdpe = [tdpe for tdpe in lsi_c2_tdpe if tdpe >= 0]
st_c3_tdpe = [tdpe for tdpe in st_c3_tdpe if tdpe >= 0]
pri_c4_tdpe = [tdpe for tdpe in pri_c4_tdpe if tdpe >= 0]
psi_c5_tdpe = [tdpe for tdpe in psi_c5_tdpe if tdpe >= 0]
prr_c6_tdpe = [tdpe for tdpe in prr_c6_tdpe if tdpe >= 0]
prs_c7_tdpe = [tdpe for tdpe in prs_c7_tdpe if tdpe >= 0]

# %% [markdown]
# # Figures

# %%
NUM_PLOTTED_CONDITIONS = 8
NUM_PLOTTED_CONDITIONS_WITH_GLOBAL = 10
NUM_CLIENTS = len(perf_dicts_lst)

# %%
all_trials_cost_lst = [lri_c0_cost, lpli_c1_cost, lsi_c2_cost, st_c3_cost, pri_c4_cost, psi_c5_cost, prr_c6_cost, prs_c7_cost]
all_trials_tdpe_lst = [lri_c0_tdpe, lpli_c1_tdpe, lsi_c2_tdpe, st_c3_tdpe, pri_c4_tdpe, psi_c5_tdpe, prr_c6_tdpe, prs_c7_tdpe]

# %%
cmap = cm.get_cmap('tab10', NUM_CLIENTS)

# %% [markdown]
# ## Test Loss Plots

# %%
all_trials_lst = all_trials_cost_lst

# Set up the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Define x-tick labels and corresponding subgroup labels
x_labels = ['Local Random Init', 'Local Prev Init', 'Local Sims Init', 'Static Trial', 'PFA Random Init', 'PFA Sims Init', 'PFA Running Random', 'PFA Running Sims']
subgroup_labels = ['Intra-subject', 'Cross-subject naive', 'Cross-subject\nspecialized']

# Positions for the boxplots
positions = np.arange(len(x_labels))

# Plotting the boxplots with transparent boxes
boxplot_elements = ax.boxplot(all_trials_lst, positions=positions, widths=0.6, patch_artist=True)

# Set the transparency for the boxes
for box in boxplot_elements['boxes']:
    box.set_facecolor('lightblue')  # Set box color
    box.set_alpha(0.3)  # Set transparency (0: fully transparent, 1: fully opaque)

for i in range(NUM_PLOTTED_CONDITIONS):
    # Scatter plot of points for each trial
    #ax.scatter([i]*NUM_CLIENTS, all_trials_lst[i], alpha=0.7, color='blue')
    for j in range(NUM_CLIENTS):
        ax.scatter([i], all_trials_lst[i][j], alpha=0.7, color=cmap(j))

# Set the x-tick labels
ax.set_xticks(positions)
ax.set_xticklabels(x_labels, fontsize=12, rotation=45)

# Adding vertical lines for separation
#ax.axvline(x=2.5, color='gray', linestyle='--', linewidth=1)
#ax.axvline(x=4.5, color='gray', linestyle='--', linewidth=1)

# Get axis limits and adjust text positioning accordingly
ax = plt.gca()  # Get current axis
ylim = ax.get_ylim()  # Get y-axis limits
# Place text closer to the x-axis based on ylim
y_position = ylim[0] + 0.1 * (ylim[1] - ylim[0])  # Adjust the position just below the x-axis
# Adding subgroup labels below the x-tick labels with better positioning
#ax.text(1, y_position, 'Intra-subject', ha='center', fontsize=12, weight='bold')
#ax.text(3.5, y_position, 'Cross-subject naive', ha='center', fontsize=12, weight='bold')
#ax.text(5, y_position, 'Cross-subject\nspecialized', ha='center', fontsize=12, weight='bold')

ax.axvline(x=2.5, color='gray', linestyle='--', linewidth=1)
ax.axvline(x=3.5, color='gray', linestyle='--', linewidth=1)

# Axis labels
ax.set_ylabel("Loss", fontsize=14, fontweight='bold')
ax.set_xlabel("Conditions", fontsize=14, fontweight='bold')
ax.set_title(f"{NUM_CLIENTS} User Experiment: Final Test Loss", fontsize=16, fontweight='bold')
# MANUALLY EXCLUDING TRIAL THAT BLEW UP!
ax.set_ylim(0.0, 1.5)

# Remove top and right plot borders
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.grid(False)

# Tight layout for better spacing
#plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Position Error Plots

# %%
all_trials_lst = all_trials_tdpe_lst

# Set up the plot
fig, ax = plt.subplots(figsize=(10, 6))

# Define x-tick labels and corresponding subgroup labels
x_labels = ['Local Random Init', 'Local Prev Init', 'Local Sims Init', 'Static Trial', 'PFA Random Init', 'PFA Sims Init', 'PFA Running Random', 'PFA Running Sims']
subgroup_labels = ['Intra-subject', 'Cross-subject naive', 'Cross-subject\nspecialized']

# Positions for the boxplots
positions = np.arange(len(x_labels))

# Plotting the boxplots with transparent boxes
boxplot_elements = ax.boxplot(all_trials_lst, positions=positions, widths=0.6, patch_artist=True)

# Set the transparency for the boxes
for box in boxplot_elements['boxes']:
    box.set_facecolor('lightblue')  # Set box color
    box.set_alpha(0.3)  # Set transparency (0: fully transparent, 1: fully opaque)

# Plotting the scatter points over the boxplots
for i in range(NUM_PLOTTED_CONDITIONS):
    # Scatter plot of points for each trial
    #ax.scatter([i]*NUM_CLIENTS, all_trials_lst[i], alpha=0.7, color='blue')
    for j in range(NUM_CLIENTS):
        ax.scatter([i], all_trials_lst[i][j], alpha=0.7, color=cmap(j))

# Set the x-tick labels
ax.set_xticks(positions)
ax.set_xticklabels(x_labels, fontsize=12, rotation=45)

# Adding vertical lines for separation
ax.axvline(x=2.5, color='gray', linestyle='--', linewidth=1)
ax.axvline(x=3.5, color='gray', linestyle='--', linewidth=1)

# Get axis limits and adjust text positioning accordingly
ax = plt.gca()  # Get current axis
ylim = ax.get_ylim()  # Get y-axis limits
# Place text closer to the x-axis based on ylim
y_position = ylim[0] + 0.1 * (ylim[1] - ylim[0])  # Adjust the position just below the x-axis
# Adding subgroup labels below the x-tick labels with better positioning
#ax.text(1, y_position, 'Intra-subject', ha='center', fontsize=12, weight='bold')
#ax.text(3.5, y_position, 'Cross-subject naive', ha='center', fontsize=12, weight='bold')
#ax.text(5, y_position, 'Cross-subject\nspecialized', ha='center', fontsize=12, weight='bold')

# Axis labels
ax.set_ylabel("Position Error", fontsize=14, fontweight='bold')
ax.set_xlabel("Trials", fontsize=14, fontweight='bold')
ax.set_title(f"{NUM_CLIENTS} User Experiment: Final Time Domain Position Error", fontsize=16, fontweight='bold')

# Customizing fonts globally (optional, can be changed)
plt.rcParams.update({
    'font.family': 'serif',  # Choose a serif font
    'font.serif': ['Times New Roman'],  # Set to Times New Roman (if available)
    'font.size': 14,  # Adjust default font size
    'axes.titlesize': 16,  # Title font size
    'axes.labelsize': 14,  # Label font size
    'legend.fontsize': 12,  # Legend font size
})

# Remove top and right plot borders
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.grid(False)

# Tight layout for better spacing
#plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Running Model Performances Across Users

# %%
pfarr_final_perfs_by_client = [perf_dict['Block1_C6_pfa_running_random']['mean_cost'] for perf_dict in perf_dicts_lst]
pfars_final_perfs_by_client = [perf_dict['Block1_C7_pfa_running_sim']['mean_cost'] for perf_dict in perf_dicts_lst]

# %%
# Set up the plot
fig, ax = plt.subplots(figsize=(10, 6))
dot_size = 150

# Define x-tick labels and corresponding subgroup labels
x_labels_idx = range(len(pfarr_final_perfs_by_client))
x_labels = [f'S{i-1+100}' for i in x_labels_idx]

# Plotting the scatter points over the boxplots
for i in x_labels_idx:
    # Scatter plot of points for each trial
    if i==0:
        ax.scatter([i], pfarr_final_perfs_by_client[i], alpha=0.7, color='blue', label=f'Random Init', s=dot_size)
        ax.scatter([i], pfars_final_perfs_by_client[i], alpha=0.7, color='orange', label=f'Sim Init', s=dot_size)
    else:
        ax.scatter([i], pfarr_final_perfs_by_client[i], alpha=0.7, color='blue', s=dot_size)
        ax.scatter([i], pfars_final_perfs_by_client[i], alpha=0.7, color='orange', s=dot_size)

# Set the x-tick labels
#ax.set_xticks(positions)
ax.set_xticklabels(x_labels, fontsize=12) #, rotation=45

# Get axis limits and adjust text positioning accordingly
ax = plt.gca()  # Get current axis
# Axis labels
ax.set_ylabel("Loss", fontsize=14, fontweight='bold')
ax.set_xlabel("Users In Sequential", fontsize=14, fontweight='bold')
ax.set_title("Block 1 Running Model Test Losses As A Function of Sequential User", fontsize=16, fontweight='bold')
ax.legend()

# Customizing fonts globally (optional, can be changed)
plt.rcParams.update({
    'font.family': 'serif',  # Choose a serif font
    'font.serif': ['Times New Roman'],  # Set to Times New Roman (if available)
    'font.size': 14,  # Adjust default font size
    'axes.titlesize': 16,  # Title font size
    'axes.labelsize': 14,  # Label font size
    'legend.fontsize': 12,  # Legend font size
})

# Remove top and right plot borders
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.grid(False)

# Tight layout for better spacing
#plt.tight_layout()

# Show the plot
plt.show()

# %%
# Set up the plot
fig, ax = plt.subplots(figsize=(10, 6))
dot_size = 150

# Define x-tick labels and corresponding subgroup labels
x_labels_idx = range(len(pfarr_final_perfs_by_client))
x_labels = [f'S{i-1+100}' for i in x_labels_idx]

# Plotting the scatter points over the boxplots
for i in x_labels_idx:
    # Scatter plot of points for each trial
    if i==0:
        ax.scatter([i], pfarr_final_perfs_by_client[i], alpha=0.7, color='blue', label=f'Random Init', s=dot_size)
        ax.scatter([i], pfars_final_perfs_by_client[i], alpha=0.7, color='orange', label=f'Sim Init', s=dot_size)
    else:
        ax.scatter([i], pfarr_final_perfs_by_client[i], alpha=0.7, color='blue', s=dot_size)
        ax.scatter([i], pfars_final_perfs_by_client[i], alpha=0.7, color='orange', s=dot_size)

# Set the x-tick labels
#ax.set_xticks(positions)
ax.set_xticklabels(x_labels, fontsize=12) #, rotation=45

# Get axis limits and adjust text positioning accordingly
ax = plt.gca()  # Get current axis
# Axis labels
ax.set_ylabel("Loss", fontsize=14, fontweight='bold')
ax.set_xlabel("Users In Sequential Order", fontsize=14, fontweight='bold')
ax.set_title("Block 1 Running Model Test Losses As A Function of Sequential User", fontsize=16, fontweight='bold')
ax.set_ylim(0.0, 0.015)
ax.legend()

# Customizing fonts globally (optional, can be changed)
plt.rcParams.update({
    'font.family': 'serif',  # Choose a serif font
    'font.serif': ['Times New Roman'],  # Set to Times New Roman (if available)
    'font.size': 14,  # Adjust default font size
    'axes.titlesize': 16,  # Title font size
    'axes.labelsize': 14,  # Label font size
    'legend.fontsize': 12,  # Legend font size
})

# Remove top and right plot borders
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.grid(False)

# Tight layout for better spacing
#plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Set up the plot
fig, ax = plt.subplots(figsize=(10, 6))
dot_size = 150

# Define x-tick labels and corresponding subgroup labels
x_labels_idx = range(len(pfarr_final_perfs_by_client))
x_labels = [f'S{i-1+100}' for i in x_labels_idx]

# Prepare lists to store data for the lines
pfarr_values = []  # Stores values for 'Random Init'
pfars_values = []  # Stores values for 'Sim Init'

# Plotting the scatter points and storing the values for the lines
for i in x_labels_idx:
    # Append the values to lists for line plotting
    pfarr_values.append(pfarr_final_perfs_by_client[i])
    pfars_values.append(pfars_final_perfs_by_client[i])

    # Scatter plot of points for each trial
    if i == 0:
        ax.scatter([i], pfarr_final_perfs_by_client[i], alpha=0.7, color='blue', label='Random Init', s=dot_size)
        ax.scatter([i], pfars_final_perfs_by_client[i], alpha=0.7, color='orange', label='Sim Init', s=dot_size)
    else:
        ax.scatter([i], pfarr_final_perfs_by_client[i], alpha=0.7, color='blue', s=dot_size)
        ax.scatter([i], pfars_final_perfs_by_client[i], alpha=0.7, color='orange', s=dot_size)

# Plotting the lines connecting the scatter points
ax.plot(x_labels_idx, pfarr_values, color='blue', alpha=0.6, linestyle='-', linewidth=2)
ax.plot(x_labels_idx, pfars_values, color='orange', alpha=0.6, linestyle='-', linewidth=2)

# Set the x-tick labels
ax.set_xticks(x_labels_idx)
ax.set_xticklabels(x_labels, fontsize=12)

# Axis labels and title
ax.set_ylabel("Loss", fontsize=14, fontweight='bold')
ax.set_xlabel("Users In Sequential Order", fontsize=14, fontweight='bold')
ax.set_title("Block 1 Running Model Test Losses As A Function of Sequential User", fontsize=16, fontweight='bold')
#ax.set_ylim(0.0, 0.015)

# Add legend
ax.legend()

# Customizing fonts globally (optional, can be changed)
plt.rcParams.update({
    'font.family': 'serif',  # Choose a serif font
    'font.serif': ['Times New Roman'],  # Set to Times New Roman (if available)
    'font.size': 14,  # Adjust default font size
    'axes.titlesize': 16,  # Title font size
    'axes.labelsize': 14,  # Label font size
    'legend.fontsize': 12,  # Legend font size
})

# Remove top and right plot borders
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# ## Decoder Distances

# %%
block = 1
which_model = 'final'
my_subjects_lst = ['S100', 'S101', 'S102', 'S103', 'S104', 'S105', 'S106', 'S107']

conditions_names_only_lst = [
    'local_random_init', 'local_prev_local_init', 'local_sims_init', 
    'StaticTrial', 'pfa_random_init', 'pfa_sims_init', 
    'pfa_running_random', 'pfa_running_sim'
]
num_conditions = len(conditions_names_only_lst)

RUNNING_MODEL_DIR = r'C:\Users\km82\Desktop\dev\labgraph-Rice\models\decoder_initializations'

# %%
all_init_cond_models_dict = {conditions_names_only_lst[i]: [] for i in range(num_conditions)}
all_final_cond_models_dict = {conditions_names_only_lst[i]: [] for i in range(num_conditions)}

# C 0 and 4
rand_init_dec = np.load(RUNNING_MODEL_DIR + '\\pos_init_dec.npy')
# C 2 and 5
sims_init_dec = np.load(f'{RUNNING_MODEL_DIR}\\sims_inits\\cpfa_sims_init.npy')

for subject_ID_str in my_subjects_lst:
    # These ones are the same for all clients
    all_init_cond_models_dict[conditions_names_only_lst[0]].append(rand_init_dec)
    all_init_cond_models_dict[conditions_names_only_lst[4]].append(rand_init_dec)
    all_init_cond_models_dict[conditions_names_only_lst[2]].append(sims_init_dec)
    all_init_cond_models_dict[conditions_names_only_lst[5]].append(sims_init_dec)
    
    # LOAD INIT MODELS
    subject_ID_num = int(subject_ID_str[1:])
    # C 1
    prev_local = np.load(f'{RUNNING_MODEL_DIR}\\all_extracted_models\\{str(subject_ID_num)}\\local_random_init_{which_model}_model_B{block}.npy')
    all_init_cond_models_dict[conditions_names_only_lst[1]].append(prev_local)
    all_init_cond_models_dict[conditions_names_only_lst[3]].append(prev_local)
    # C6
    if subject_ID_num>100:
        prr = np.load(f'{RUNNING_MODEL_DIR}\\all_extracted_models\\{str(subject_ID_num-1)}\\pfa_running_random_{which_model}_model_B{block}.npy')
    else:
        # S100 case, use S999
        prr = np.load(f'C:\\Users\\km82\\Desktop\\dev\\labgraph-Rice\\models\\decoder_initializations\\all_extracted_models\\Piloting\\999\\pfa_running_random_{which_model}_model_B{block}.npy')
    all_init_cond_models_dict[conditions_names_only_lst[6]].append(prr)
    
    # C7
    if subject_ID_num>100:
        prs = np.load(f'{RUNNING_MODEL_DIR}\\all_extracted_models\\{str(subject_ID_num-1)}\\pfa_running_sim_{which_model}_model_B{block}.npy')
    else:
        # S100 case, use S999
        prs = np.load(f'C:\\Users\\km82\\Desktop\\dev\\labgraph-Rice\\models\\decoder_initializations\\all_extracted_models\\Piloting\\999\\pfa_running_sim_{which_model}_model_B{block}.npy')
    all_init_cond_models_dict[conditions_names_only_lst[7]].append(prs)
        
    # LOAD FINAL MODELS
    for cond_name in conditions_names_only_lst:
        all_final_cond_models_dict[cond_name].append(np.load(f'{RUNNING_MODEL_DIR}\\all_extracted_models\\{str(subject_ID_num)}\\{cond_name}_{which_model}_model_B{block}.npy'))

# %%
avg_init_model_per_cond = [np.mean(np.stack(all_init_cond_models_dict[key]), axis=0) for key in conditions_names_only_lst]
avg_final_model_per_cond = [np.mean(np.stack(all_final_cond_models_dict[key]), axis=0) for key in conditions_names_only_lst]
avg_final_dec = np.mean(avg_final_model_per_cond, axis=0)

#init_model_norm_per_cond = [np.mean(np.stack(all_init_cond_models_dict[key]), axis=0) for key in conditions_names_only_lst]
#final_model_norm_per_cond = [[np.linalg.norm(dec) for dec in all_final_cond_models_dict[key]] for key in conditions_names_only_lst]

# %%
init_model_norm_per_cond_dict = {conditions_names_only_lst[i]: [] for i in range(num_conditions)}
final_model_norm_per_cond_dict = {conditions_names_only_lst[i]: [] for i in range(num_conditions)}

rel_diff_init_model_avg_norm_per_cond_dict = {conditions_names_only_lst[i]: [] for i in range(num_conditions)}
rel_diff_final_model_avg_norm_per_cond_dict = {conditions_names_only_lst[i]: [] for i in range(num_conditions)}
rel_diff_init_model_norm_per_cond_dict = {conditions_names_only_lst[i]: [] for i in range(num_conditions)}
rel_diff_final_model_norm_per_cond_dict = {conditions_names_only_lst[i]: [] for i in range(num_conditions)}

# Calculate the norm of each decoder matrix for all subjects in each condition
for key_idx, key in enumerate(conditions_names_only_lst):
    # Compute norms of each decoder matrix in the initial and final models
    init_model_norm_per_cond_dict[key].append([np.linalg.norm(dec) for dec in all_init_cond_models_dict[key]])
    final_model_norm_per_cond_dict[key].append([np.linalg.norm(dec) for dec in all_final_cond_models_dict[key]])
    
    rel_diff_init_model_avg_norm_per_cond_dict[key].append([np.linalg.norm(dec - avg_final_dec) for dec in all_init_cond_models_dict[key]])
    rel_diff_final_model_avg_norm_per_cond_dict[key].append([np.linalg.norm(dec - avg_final_dec) for dec in all_final_cond_models_dict[key]])
    
    rel_diff_init_model_norm_per_cond_dict[key].append([np.linalg.norm(dec - avg_init_model_per_cond[key_idx]) for dec in all_init_cond_models_dict[key]])
    rel_diff_final_model_norm_per_cond_dict[key].append([np.linalg.norm(dec - avg_final_model_per_cond[key_idx]) for dec in all_final_cond_models_dict[key]])

# %%
for i in range(len(my_subjects_lst)):
    print(np.linalg.norm(all_init_cond_models_dict['StaticTrial'][i] - all_final_cond_models_dict['StaticTrial'][i]))
# Out:
# 2.134836765957514
# 3.5414225661621135
# 2.169741433699392
# 2.7122153174587904
# 2.148504787856996
# 4.213893993938676
# 1.5479208894755816
# 6.055844147477662

# %% [markdown]
# Checking static trial models (last and second to last...) to see if they changed....
# - Checking Local Prev Local (eg which has same init) to see if second to last and final models have the same norms...

# %%
print("LOCAL PREV LOCAL MODEL NORMS")

for subject_ID_str in my_subjects_lst:
    # LOAD INIT MODELS
    subject_ID_num = int(subject_ID_str[1:])
    print(f"\nSubject {subject_ID_str}")
    # C 1
    prev_local = np.load(f'{RUNNING_MODEL_DIR}\\all_extracted_models\\{str(subject_ID_num)}\\local_random_init_{which_model}_model_B{block}.npy') 
    print('Prev Local model norm:')
    print(np.linalg.norm(prev_local))
    # LOAD FINAL MODELS
    print('Second to last model norm:')
    print(np.linalg.norm(np.load(f'{RUNNING_MODEL_DIR}\\all_extracted_models\\{str(subject_ID_num)}\\local_prev_local_init_second_to_last_model_B{block}.npy')))
    print('Final model norm:')
    print(np.linalg.norm(np.load(f'{RUNNING_MODEL_DIR}\\all_extracted_models\\{str(subject_ID_num)}\\local_prev_local_init_final_model_B{block}.npy')))
# Out:
# LOCAL PREV LOCAL MODEL NORMS
#
# Subject S100
# Prev Local model norm:
# 3.3398473595621825
# Second to last model norm:
# 3.5164784268298233
# Final model norm:
# 4.798733710560579
#
# Subject S101
# Prev Local model norm:
# 5.811457961916885
# Second to last model norm:
# 3.919155553997179
# Final model norm:
# 6.003241011335373
#
# Subject S102
# Prev Local model norm:
# 3.4129667575495466
# Second to last model norm:
# 3.620305030247624
# Final model norm:
# 4.988171107387377
#
# Subject S103
# Prev Local model norm:
# 3.348374218078269
# Second to last model norm:
# 4.261366610957675
# Final model norm:
# 3.6656816142676734
#
# Subject S104
# Prev Local model norm:
# 4.181192028809542
# Second to last model norm:
# 4.353132087508597
# Final model norm:
# 3.9589831676459757
#
# Subject S105
# Prev Local model norm:
# 4.622342049969207
# Second to last model norm:
# 4.734068746021129
# Final model norm:
# 4.8014881662913265
#
# Subject S106
# Prev Local model norm:
# 2.1194763593167356
# Second to last model norm:
# 2.9619642473880914
# Final model norm:
# 2.9681990782171037
#
# Subject S107
# Prev Local model norm:
# 4.620283218764882
# Second to last model norm:
# 2.5418718795518913
# Final model norm:
# 2.438851898050341

# %%
print("STATIC TRIAL MODEL NORMS")

for subject_ID_str in my_subjects_lst:
    # LOAD INIT MODELS
    subject_ID_num = int(subject_ID_str[1:])
    print(f"\nSubject {subject_ID_str}")
    # C 1
    prev_local = np.load(f'{RUNNING_MODEL_DIR}\\all_extracted_models\\{str(subject_ID_num)}\\local_random_init_{which_model}_model_B{block}.npy') 
    print('Prev Local model norm:')
    print(np.linalg.norm(prev_local))
    # LOAD FINAL MODELS
    print('Second to last model norm:')
    print(np.linalg.norm(np.load(f'{RUNNING_MODEL_DIR}\\all_extracted_models\\{str(subject_ID_num)}\\StaticTrial_second_to_last_model_B{block}.npy')))
    print('Final model norm:')
    print(np.linalg.norm(np.load(f'{RUNNING_MODEL_DIR}\\all_extracted_models\\{str(subject_ID_num)}\\StaticTrial_final_model_B{block}.npy')))
# Out:
# STATIC TRIAL MODEL NORMS
#
# Subject S100
# Prev Local model norm:
# 3.3398473595621825
# Second to last model norm:
# 2.9874239737668526
# Final model norm:
# 2.9874239737668526
#
# Subject S101
# Prev Local model norm:
# 5.811457961916885
# Second to last model norm:
# 5.407115469043498
# Final model norm:
# 5.407115469043498
#
# Subject S102
# Prev Local model norm:
# 3.4129667575495466
# Second to last model norm:
# 3.1453602442897917
# Final model norm:
# 3.1453602442897917
#
# Subject S103
# Prev Local model norm:
# 3.348374218078269
# Second to last model norm:
# 4.575970138954225
# Final model norm:
# 4.575970138954225
#
# Subject S104
# Prev Local model norm:
# 4.181192028809542
# Second to last model norm:
# 4.595039754839131
# Final model norm:
# 4.595039754839131
#
# Subject S105
# Prev Local model norm:
# 4.622342049969207
# Second to last model norm:
# 3.9930155196861183
# Final model norm:
# 3.9930155196861183
#
# Subject S106
# Prev Local model norm:
# 2.1194763593167356
# Second to last model norm:
# 2.532996382748222
# Final model norm:
# 2.532996382748222
#
# Subject S107
# Prev Local model norm:
# 4.620283218764882
# Second to last model norm:
# 3.4389929038020295
# Final model norm:
# 3.4389929038020295

# %%
# Define the keys
keys = [ 
    'local_random_init', 'local_prev_local_init', 'local_sims_init', 
    'StaticTrial', 'pfa_random_init', 'pfa_sims_init', 
    'pfa_running_random', 'pfa_running_sim'
]

# Optionally, you can set colors for the boxes
colors = ['lightblue', 'lightgreen', 'lightpink', 'lightyellow', 'lightcoral', 
          'lightgray', 'lightcyan', 'lightgoldenrodyellow']

# %%
# Extract the lists of floats (norm differences) from the dictionary
data_for_boxplot = [rel_diff_init_model_norm_per_cond_dict[key][0] for key in keys]

fig, ax = plt.subplots(figsize=(12, 8))
bplot = ax.boxplot(data_for_boxplot, patch_artist=True, showfliers=False)
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)

ax.set_xticklabels(keys, fontsize=12, rotation=45, ha='right')
ax.set_ylabel('Relative Difference (Norm)', fontsize=14)
ax.set_title('INITIAL: Relative Difference (Frobenius Norms) of Conditions Models Vs Avg Cond Model', fontsize=16)

plt.tight_layout()
plt.show()

# %%
# Extract the lists of floats (norm differences) from the dictionary
data_for_boxplot = [rel_diff_final_model_norm_per_cond_dict[key][0] for key in keys]

fig, ax = plt.subplots(figsize=(12, 8))
bplot = ax.boxplot(data_for_boxplot, patch_artist=True, showfliers=False)
for patch, color in zip(bplot['boxes'], colors):
    patch.set_facecolor(color)

ax.set_xticklabels(keys, fontsize=12, rotation=45, ha='right')
ax.set_ylabel('Relative Difference (Norm)', fontsize=14)
ax.set_title('Frobenius Norm Between Final Model Weights Within Each Condition', fontsize=16)

plt.tight_layout()
plt.show()
